# %%
import os
import boto3
from google.colab import drive

def download_file_from_s3_and_save_to_drive(aws_access_key_id, aws_secret_access_key, bucket_name, file_name, drive_folder):
    # Google 드라이브 마운트
    drive.mount('/gdrive')

    # AWS S3 클라이언트 생성
    s3_client = boto3.client('s3', aws_access_key_id=AKIAV4XWM7IFRL2RGIF4, aws_secret_access_key=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)

    # S3 버킷에서 파일 가져오기
    drive_folder = '/gdrive/My Drive/PHODO/Segmentation Model/Yolo_custom/originalImage'

    # Google 드라이브에 파일 저장
    drive_file_path = os.path.join(drive_folder, file_name)  # Google 드라이브에 저장할 파일 경로
    with open(drive_file_path, 'wb') as f:
      s3_client.download_fileobj(bucket_name, file_name, f)

    print('File downloaded and saved to Google Drive:', drive_file_path)

# Colab API 함수 등록
api_key = 'YOUR_COLAB_API_KEY'
function_name = 'download_file_from_s3_and_save_to_drive'
function_code = '''
import os
import boto3
from google.colab import drive

def download_file_from_s3_and_save_to_drive(aws_access_key_id, aws_secret_access_key, bucket_name, file_name, drive_folder):
    # Google 드라이브 마운트
    drive.mount('/gdrive')

    # AWS S3 클라이언트 생성
    s3_client = boto3.client('s3', aws_access_key_id=AKIAV4XWM7IFRL2RGIF4, aws_secret_access_key=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)

    # S3 버킷에서 파일 가져오기
    drive_folder = '/gdrive/My Drive/PHODO/Segmentation Model/Yolo_custom/originalImage'

    # Google 드라이브에 파일 저장
    drive_file_path = os.path.join(drive_folder, file_name)  # Google 드라이브에 저장할 파일 경로
    with open(drive_file_path, 'wb') as f:
      s3_client.download_fileobj(bucket_name, file_name, f)

    print('File downloaded and saved to Google Drive:', drive_file_path)
'''

# Colab API 등록
# !pip install colabcode
from colabcode import ColabCode
colab = ColabCode(api_key=api_key)
colab.run_app(code=function_code, function_name=function_name)
